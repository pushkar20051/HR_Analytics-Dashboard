# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Cleaned_HR_Data_Analysis.csv")
df
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 0            3427  20-Sep-19  Production Technician I         CCDR
# 1            3428  11-Feb-23  Production Technician I           EW
# 2            3429  10-Dec-18       Area Sales Manager           PL
# 3            3430  21-Jun-21       Area Sales Manager         CCDR
# 4            3431  29-Jun-19       Area Sales Manager          TNS
# ...           ...        ...                      ...          ...
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0            Active     Contract  Zone C                  Temporary
# ...

# %%
df.head(10)
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 3         3430  21-Jun-21       Area Sales Manager         CCDR
# 4         3431  29-Jun-19       Area Sales Manager          TNS
# 5         3432  17-Jan-20       Area Sales Manager          BPC
# 6         3433  06-Apr-22       Area Sales Manager          WBL
# 7         3434  06-Nov-20       Area Sales Manager         CCDR
# 8         3435  18-Aug-18       Area Sales Manager          NEL
# 9         3436  21-Jan-22       Area Sales Manager          BPC
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# ...

# %%
df.tail()
# Out:
#       Employee ID  StartDate                    Title BusinessUnit  \
# 2840         3421  09-May-22  Production Technician I           PL
# 2841         3423  28-Dec-20  Production Technician I          SVG
# 2842         3424  09-Dec-20  Production Technician I          TNS
# 2843         3425  28-May-19  Production Technician I          WBL
# 2844         3426  27-Apr-22  Production Technician I          BPC
#
#      EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 2840         Active    Part-Time  Zone A                  Part-Time
# 2841         Active    Part-Time  Zone A                  Full-Time
# 2842     Terminated     Contract  Zone B                  Temporary
# 2843     Terminated     Contract  Zone B                  Full-Time
# 2844         Active    Full-Time  Zone B                  Temporary
#
#          DepartmentType               Division  ... Engagement Score  \
# 2840  Production                      Wireless  ...                5
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2845 entries, 0 to 2844
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee ID                 2845 non-null   int64
#  1   StartDate                   2845 non-null   str
#  2   Title                       2845 non-null   str
#  3   BusinessUnit                2845 non-null   str
#  4   EmployeeStatus              2845 non-null   str
#  5   EmployeeType                2845 non-null   str
#  6   PayZone                     2845 non-null   str
#  7   EmployeeClassificationType  2845 non-null   str
#  8   DepartmentType              2845 non-null   str
#  9   Division                    2845 non-null   str
#  10  DOB                         2845 non-null   str
#  11  State                       2845 non-null   str
#  12  GenderCode                  2845 non-null   str
#  13  RaceDesc                    2845 non-null   str
# ...

# %%
df.describe()
# Out:
#        Employee ID  Current Employee Rating  Engagement Score  \
# count  2845.000000              2845.000000       2845.000000
# mean   2470.591916                 2.974692          2.941652
# std     859.450107                 1.012610          1.435230
# min    1001.000000                 1.000000          1.000000
# 25%    1736.000000                 2.000000          2.000000
# 50%    2456.000000                 3.000000          3.000000
# 75%    3197.000000                 3.000000          4.000000
# max    4000.000000                 5.000000          5.000000
#
#        Satisfaction Score  Work-Life Balance Score  Training Duration(Days)  \
# count         2845.000000              2845.000000              2845.000000
# mean             3.028471                 2.989104                 2.973989
# std              1.410067                 1.408816                 1.419682
# min              1.000000                 1.000000                 1.000000
# ...

# %%
df.describe(include='O')
# Out:
#         StartDate                    Title BusinessUnit EmployeeStatus  \
# count        2845                     2845         2845           2845
# unique       1472                       32           10              2
# top     04-Mar-22  Production Technician I          NEL         Active
# freq            7                     1241          291           2458
#
#        EmployeeType PayZone EmployeeClassificationType     DepartmentType  \
# count          2845    2845                       2845               2845
# unique            3       3                          3                  6
# top       Full-Time  Zone A                  Temporary  Production
# freq            997    1013                        980               1910
#
#                 Division         DOB State GenderCode RaceDesc MaritalDesc  \
# count               2845        2845  2845       2845     2845        2845
# unique                25        2664    28          2        5           4
# ...

# %%
df.columns.tolist()
# Out:
# ['Employee ID',
#  'StartDate',
#  'Title',
#  'BusinessUnit',
#  'EmployeeStatus',
#  'EmployeeType',
#  'PayZone',
#  'EmployeeClassificationType',
#  'DepartmentType',
#  'Division',
#  'DOB',
#  'State',
#  'GenderCode',
#  'RaceDesc',
#  'MaritalDesc',
#  'Performance Score',
#  'Current Employee Rating',
#  'Survey Date',
#  'Engagement Score',
#  'Satisfaction Score',
#  'Work-Life Balance Score',
#  'Training Date',
#  'Training Program Name',
#  'Training Type',
#  'Training Outcome',
#  'Training Duration(Days)',
#  'Training Cost',
#  'Age']

# %%
df.isna().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
most_common_agegroup = df["Age"].mode()[0]
df["Age"].fillna(most_common_agegroup, inplace=True)
# Out:
# 0       50
# 1       58
# 2       27
# 3       23
# 4       50
#         ..
# 2840    63
# 2841    19
# 2842    23
# 2843    65
# 2844    32
# Name: Age, Length: 2845, dtype: int64

# %%
df.isna().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
df["MaritalDesc"].unique()
# Out:
# <StringArray>
# ['Widowed', 'Single', 'Married', 'Divorced']
# Length: 4, dtype: str

# %%
df["MaritalDesc"].value_counts()
# Out:
# MaritalDesc
# Single      731
# Married     730
# Divorced    700
# Widowed     684
# Name: count, dtype: int64

# %%
score_map = {
    "PIP": 1,
    "Needs Improvement": 2,
    "Fully Meets": 3,
    "Exceeds": 4
}

df["Performance_Score_Num"] = df["Performance Score"].map(score_map)

# %%
marital_map = {
    "Single": 1,
    "Married": 2,
    "Divorced": 3,
    "Separated": 4,
    "Widowed": 5
}

df["MaritalDesc_Num"] = df["MaritalDesc"].map(marital_map)

# %%
df.groupby("MaritalDesc_Num")["Performance_Score_Num"].mean()
# Out:
# MaritalDesc_Num
# 1    2.972640
# 2    3.028767
# 3    2.998571
# 5    3.017544
# Name: Performance_Score_Num, dtype: float64

# %%
overall_mean = df["Performance_Score_Num"].mean()

group_mean = df.groupby("MaritalDesc")["Performance_Score_Num"].mean()

difference = group_mean - overall_mean

difference
# Out:
# MaritalDesc
# Divorced   -0.005646
# Married     0.024549
# Single     -0.031578
# Widowed     0.013326
# Name: Performance_Score_Num, dtype: float64

# %%
group_mean["Married"] - group_mean["Single"]
# Out:
# np.float64(0.05612690440942236)

# %%
df["Satisfaction Score"].unique()
# Out:
# array([2, 1, 5, 3, 4])

# %%
df.groupby("MaritalDesc_Num")["Satisfaction Score"].mean()
# Out:
# MaritalDesc_Num
# 1    3.045144
# 2    3.028767
# 3    3.084286
# 5    2.953216
# Name: Satisfaction Score, dtype: float64

# %%
df["Work-Life Balance Score"].unique()
# Out:
# array([3, 5, 1, 4, 2])

# %%
df.groupby("MaritalDesc_Num")["Work-Life Balance Score"].mean()
# Out:
# MaritalDesc_Num
# 1    2.980848
# 2    2.979452
# 3    2.950000
# 5    3.048246
# Name: Work-Life Balance Score, dtype: float64

# %%
df["GenderCode"].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
gende_map={
"Female":0,
 "Male":1,    
}
df["gender_num"]=df["GenderCode"].map(gende_map)

# %%
df["gender_num"].unique()
# Out:
# array([0, 1])

# %%
df.groupby("gender_num")["Performance_Score_Num"].mean()
# Out:
# gender_num
# 0    3.017003
# 1    2.988067
# Name: Performance_Score_Num, dtype: float64

# %%
df.groupby("DepartmentType")["Performance_Score_Num"].mean()
# Out:
# DepartmentType
# Admin Offices           3.075949
# Executive Office        2.583333
# IT/IS                   2.963325
# Production              3.012042
# Sales                   3.025723
# Software Engineering    3.000000
# Name: Performance_Score_Num, dtype: float64

# %%
df.groupby("EmployeeType")["Performance_Score_Num"].mean()
# Out:
# EmployeeType
# Contract     3.015773
# Full-Time    2.995988
# Part-Time    3.001115
# Name: Performance_Score_Num, dtype: float64

# %%
bins = [20, 30, 40, 50, 60]
labels = ["20-30", "30-40", "40-50", "50-60"]

df["AgeGroup"] = pd.cut(df["Age"], bins=bins, labels=labels)

df.groupby("AgeGroup")["Performance_Score_Num"].mean()
# Out:
# AgeGroup
# 20-30    3.004032
# 30-40    3.011038
# 40-50    2.976744
# 50-60    3.015766
# Name: Performance_Score_Num, dtype: float64

# %%
df.groupby("Training Duration(Days)")["Performance_Score_Num"].mean()
# Out:
# Training Duration(Days)
# 1    3.025510
# 2    3.000000
# 3    3.008636
# 4    2.975836
# 5    3.008803
# Name: Performance_Score_Num, dtype: float64

# %%
df.groupby("Training Type")["Performance_Score_Num"].mean()
# Out:
# Training Type
# External    3.010534
# Internal    2.997889
# Name: Performance_Score_Num, dtype: float64

# %%
group = df.groupby("MaritalDesc")["Performance_Score_Num"].mean()

plt.bar(group.index, group.values)
plt.title("Average Performance by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Average Performance")
plt.show()

# %%
group = df.groupby("GenderCode")["Performance_Score_Num"].mean()

plt.bar(group.index, group.values)
plt.title("Performance by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Performance")
plt.show()

# %%
group = df.groupby("Age")["Performance_Score_Num"].mean()

plt.plot(group.index, group.values)
plt.title("Performance vs Age")
plt.xlabel("Age")
plt.ylabel("Performance")
plt.show()

# %%
plt.scatter(df["Satisfaction Score"], df["Performance_Score_Num"])
plt.title("Satisfaction vs Performance")
plt.xlabel("Satisfaction Score")
plt.ylabel("Performance Score")
plt.show()

# %%
group = df.groupby("DepartmentType")["Performance_Score_Num"].mean()

plt.bar(group.index, group.values)
plt.xticks(rotation=45)
plt.title("Performance by Department")
plt.xlabel("Department")
plt.ylabel("Average Performance")
plt.show()

# %%
group = df.groupby("Training Duration(Days)")["Performance_Score_Num"].mean()
plt.figure(figsize=(9,6))
plt.plot(group.index, group.values, marker='o')
plt.title("Performance vs Training Duration")
plt.xlabel("Training Duration (Days)")
plt.ylabel("Average Performance")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
